# %%
import pandas as pd
df = pd.load_csv("./locustfile.py")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 df = pd.load_csv("./locustfile.py")
#
# AttributeError: module 'pandas' has no attribute 'load_csv'
